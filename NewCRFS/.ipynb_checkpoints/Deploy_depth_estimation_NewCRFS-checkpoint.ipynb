# %% [markdown]
# ## Setup

# %%
import numpy as np
import time
import json
import requests
import boto3
import os
import sagemaker
import io

# %%
from sagemaker.pytorch.model import PyTorchModel
from sagemaker.predictor import Predictor

# %%
from time import strftime,gmtime

# %%
import matplotlib.pyplot as plt
import cv2

# %%
import boto3
sns_client = boto3.client('sns')
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
from sagemaker import get_execution_role, Session, image_uris

role = get_execution_role()
sess = Session()
region = sess.boto_region_name
bucket = sess.default_bucket()
sm_client = boto3.client("sagemaker", region_name=region)

# %%
boto_session = boto3.session.Session()
sm_runtime = boto_session.client("sagemaker-runtime")

# %% [markdown]
# ## Load model drive

# %%
# !wget https://virutalbuy-public.oss-cn-hangzhou.aliyuncs.com/share/newcrfs/models/model_kittieigen.ckpt
# Out:
# --2022-10-11 06:22:35--  https://virutalbuy-public.oss-cn-hangzhou.aliyuncs.com/share/newcrfs/models/model_kittieigen.ckpt
# Resolving virutalbuy-public.oss-cn-hangzhou.aliyuncs.com (virutalbuy-public.oss-cn-hangzhou.aliyuncs.com)... 118.31.232.219
# Connecting to virutalbuy-public.oss-cn-hangzhou.aliyuncs.com (virutalbuy-public.oss-cn-hangzhou.aliyuncs.com)|118.31.232.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1082597759 (1.0G) [application/octet-stream]
# Saving to: ‘model_kittieigen.ckpt’
#
# model_kittieigen.ck 100%[===================>]   1.01G  6.30MB/s    in 2m 47s
#
# 2022-10-11 06:25:23 (6.18 MB/s) - ‘model_kittieigen.ckpt’ saved [1082597759/1082597759]

# %%
# !mv model_kittieigen.ckpt model.pth

# %% [markdown]
# ### Create model archive

# %%
model_archive_name = 'NewCRFS.tar.gz'

# %%
# !tar -cvzf {model_archive_name} model.pth code/
# Out:
# model.pth
# code/
# code/newcrfs/
# code/newcrfs/utils.py
# code/newcrfs/networks/
# code/newcrfs/networks/newcrf_layers.py
# code/newcrfs/networks/newcrf_utils.py
# code/newcrfs/networks/uper_crf_head.py
# code/newcrfs/networks/__init__.py
# code/newcrfs/networks/NewCRFDepth.py
# code/newcrfs/networks/swin_transformer.py
# code/newcrfs/.ipynb_checkpoints/
# code/requirements.txt
# code/inference.py
# code/.ipynb_checkpoints/

# %%
# model package tarball (model artifact + inference code)
model_url = sess.upload_data(path=model_archive_name, key_prefix='NewCRFS_model')
print('model uploaded to: {}'.format(model_url))
# Out:
# model uploaded to: s3://sagemaker-ca-central-1-333752261573/NewCRFS_model/NewCRFS.tar.gz

# %% [markdown]
# ### Create model and test inference

# %%
framework_version = '1.7.1'
py_version = 'py36'
env= {
            'TS_MAX_REQUEST_SIZE': '100000000', #default max request size is 6 Mb for torchserve, need to update it to support the 70 mb input payload
            'TS_MAX_RESPONSE_SIZE': '100000000',
            'TS_DEFAULT_RESPONSE_TIMEOUT': '1000'
        }

sm_model = PyTorchModel(model_data=model_url,
                               framework_version=framework_version,
                               role=role,
                               sagemaker_session=sess,
                               entry_point='inference.py',
                               source_dir= 'code',
                               env=env,
                               py_version=py_version
                              )

# %%
instance_type = 'ml.g4dn.xlarge'
uncompiled_predictor = sm_model.deploy(initial_instance_count=1, instance_type=instance_type)
# Out:
# -----------!

# %% [markdown]
# # Prediction

# %%
import boto3
import requests
client = boto3.client('sagemaker-runtime', region_name=region)
content_type = 'application/x-image'

# %%
# test sample 2
frame_number= 242

#path= f'test_data/frame{frame_number}.jpg'

path = 'test_data/0000000008.png'

img = cv2.imread(path)
#img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

body = io.open(path, 'rb')

# %%
t0 = time.time()
rv = client.invoke_endpoint(EndpointName=uncompiled_predictor.endpoint_name, Body=body, ContentType=content_type)
t1 = time.time()

time_elapsed = (t1-t0)*1000
print(time_elapsed)
# Out:
# 559.7732067108154

# %%
predictions= json.loads(rv['Body'].read().decode())

# %%
type(predictions)
# Out:
# list

# %%
predictions_arr = np.array(predictions)

# %%
predictions_arr.shape
# Out:
# (480, 640)

# %%
predictions_arr= predictions_arr.astype(np.float32)
predictions_arr= cv2.resize(predictions_arr, (1216, 352), interpolation=cv2.INTER_LINEAR)

# %%
f, axarr = plt.subplots(1,2)

f.set_figheight(7.04)
f.set_figwidth(24.32)


axarr[0].imshow(img)
axarr[1].imshow(predictions_arr, cmap='plasma')

axarr[0].set_axis_off()
axarr[1].set_axis_off()

# %%
# save plot
f.savefig(f'output_result/{frame_number}.png')

# %% [markdown]
# # Measure invocation time

# %%
inferenceTime_list=[]
for i in range(100):
    body = io.open(path, 'rb')
    t0 = time.time()
    rv = client.invoke_endpoint(EndpointName=uncompiled_predictor.endpoint_name, Body=body, ContentType=content_type)
    t1 = time.time()

    time_elapsed = (t1-t0)*1000
    inferenceTime_list.append(time_elapsed)
    #print(time_elapsed)

# %%
np.mean(inferenceTime_list)
# Out:
# 555.7001662254333

# %% [markdown]
# # Async endpoint

# %%
from sagemaker.async_inference.async_inference_config import AsyncInferenceConfig

bucket= 'gulogulo-inference-results'

async_config = AsyncInferenceConfig(
                output_path= f"s3://{bucket}/output",
                max_concurrent_invocations_per_instance=2,)

# %%
framework_version = '1.7.1'
py_version = 'py36'
env= {
            'TS_MAX_REQUEST_SIZE' : '1000000000', #default max request size is 6 Mb for torchserve, need to update it to support the 70 mb input payload
            'TS_MAX_RESPONSE_SIZE': '1000000000',
            'TS_DEFAULT_RESPONSE_TIMEOUT': '1000'
        }

sm_model = PyTorchModel(model_data=model_url,
                               framework_version=framework_version,
                               role=role,
                               sagemaker_session=sess,
                               entry_point='inference.py',
                               source_dir= 'code-async',
                               env=env,
                               py_version=py_version
                              )

# %%
instance_type = 'ml.g4dn.xlarge'

async_uncompiled_predictor = sm_model.deploy(async_inference_config=async_config,
                                       initial_instance_count=1,
                                       instance_type=instance_type)

# %% [markdown]
# # Test endpoint

# %%
endpoint_name= 'pytorch-inference-2022-10-09-08-01-56-385'

# %%
input_1_s3_location= 's3://gulogulo-inference-images/frame92.jpg'

# %%
input_1_s3_location= 's3://gulogulo-inference-images/GuloGulo_2022_09_26_15_02_53.mp4'

# %%
input_1_s3_location= 's3://gulogulo-inference-images/Week_0-2_planar2.mp4'

# %%
input_1_s3_location= 's3://gulogulo-inference-images/GuloGulo_2022_09_26_15_07_11.mp4'

# %% [markdown]
# ### Invoke async endpoint

# %%
response = sm_runtime.invoke_endpoint_async(
    EndpointName=endpoint_name, 
    InputLocation=input_1_s3_location)
output_location = response['OutputLocation']
print(f"OutputLocation: {output_location}")
